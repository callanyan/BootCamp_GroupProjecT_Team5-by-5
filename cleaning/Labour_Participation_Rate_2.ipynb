# %%
import requests
import json
from pprint import pprint
import pandas as pd
import numpy as np
import os
import csv
import matplotlib.pyplot as plt

# %%
query_url = 'https://api.ed.gov/data/mbk-labor-force-participation?'
api_key = 'api_key=bVIf4sU0IzjYfs473ZQEyzOjmZ5hkWeG6vdk5vPc'
per_page = 'per_page=' + '1258'
full_url = query_url + api_key + "&" + per_page

labour_data = requests.get(full_url).json()
pprint(labour_data)
# Out:
# {'pagination': {'count': 1258, 'page': 1, 'pages': 1, 'per_page': 1258},
#  'resources': [{'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '74.1',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.29',
#                 'Year': '1980',
#                 'index': 0},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '74',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.29',
#                 'Year': '1981',
#                 'index': 1},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '73.6',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.29',
#                 'Year': '1982',
#                 'index': 2},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '73.7',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.29',
#                 'Year': '1983',
#                 'index': 3},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '74.2',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.29',
#                 'Year': '1984',
#                 'index': 4},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '74.8',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.3',
#                 'Year': '1985',
#                 'index': 5},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '75.3',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.3',
#                 'Year': '1986',
#                 'index': 6},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '75.1',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.3',
#                 'Year': '1987',
#                 'index': 7},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '75',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.3',
#                 'Year': '1988',
#                 'index': 8},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '74.9',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.31',
#                 'Year': '1989',
#                 'index': 9},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '73.7',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.3',
#                 'Year': '1990',
#                 'index': 10},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '72.8',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.31',
#                 'Year': '1991',
#                 'index': 11},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '73.1',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.31',
#                 'Year': '1992',
#                 'index': 12},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '73.1',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.31',
#                 'Year': '1993',
#                 'index': 13},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '73',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.31',
#                 'Year': '1994',
#                 'index': 14},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '73',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.32',
#                 'Year': '1995',
#                 'index': 15},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '72.7',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.32',
#                 'Year': '1996',
#                 'index': 16},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '73.1',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.32',
#                 'Year': '1997',
#                 'index': 17},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '73.2',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.31',
#                 'Year': '1998',
#                 'index': 18},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '73',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.31',
#                 'Year': '1999',
#                 'index': 19},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '73.4',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.31',
#                 'Year': '2000',
#                 'index': 20},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '72.3',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.31',
#                 'Year': '2001',
#                 'index': 21},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '71.6',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.31',
#                 'Year': '2002',
#                 'index': 22},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '70.4',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.31',
#                 'Year': '2003',
#                 'index': 23},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '70.1',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.31',
#                 'Year': '2004',
#                 'index': 24},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '69.8',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.31',
#                 'Year': '2005',
#                 'index': 25},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '69.8',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.31',
#                 'Year': '2006',
#                 'index': 26},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '69',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.31',
#                 'Year': '2007',
#                 'index': 27},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '68.7',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.31',
#                 'Year': '2008',
#                 'index': 28},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '66.8',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.31',
#                 'Year': '2009',
#                 'index': 29},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '65.3',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.31',
#                 'Year': '2010',
#                 'index': 30},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '64.9',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.31',
#                 'Year': '2011',
#                 'index': 31},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '64.7',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.31',
#                 'Year': '2012',
#                 'index': 32},
#                {'Age': None,
#                 'Characteristic': 'Total',
#                 'Note on Percent': None,
#                 'Percentage': '64.7',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.31',
#                 'Year': '2013',
#                 'index': 33},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '66.5',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.54',
#                 'Year': '1980',
#                 'index': 34},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '65.6',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.55',
#                 'Year': '1981',
#                 'index': 35},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '64.5',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.55',
#                 'Year': '1982',
#                 'index': 36},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '64.6',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.56',
#                 'Year': '1983',
#                 'index': 37},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '64.9',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.57',
#                 'Year': '1984',
#                 'index': 38},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '65.3',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.58',
#                 'Year': '1985',
#                 'index': 39},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '65.2',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.59',
#                 'Year': '1986',
#                 'index': 40},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '64.8',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.59',
#                 'Year': '1987',
#                 'index': 41},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '65.5',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.58',
#                 'Year': '1988',
#                 'index': 42},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '65.8',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.57',
#                 'Year': '1989',
#                 'index': 43},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '63.7',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.57',
#                 'Year': '1990',
#                 'index': 44},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '62.4',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.59',
#                 'Year': '1991',
#                 'index': 45},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '62.4',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.6',
#                 'Year': '1992',
#                 'index': 46},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '62.6',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.6',
#                 'Year': '1993',
#                 'index': 47},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '62.5',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.6',
#                 'Year': '1994',
#                 'index': 48},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '63.9',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.59',
#                 'Year': '1995',
#                 'index': 49},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '62.6',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.59',
#                 'Year': '1996',
#                 'index': 50},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '62.6',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.58',
#                 'Year': '1997',
#                 'index': 51},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '63.5',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.57',
#                 'Year': '1998',
#                 'index': 52},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '62.6',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.56',
#                 'Year': '1999',
#                 'index': 53},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '63.1',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.56',
#                 'Year': '2000',
#                 'index': 54},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '60.9',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.57',
#                 'Year': '2001',
#                 'index': 55},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '59.7',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.57',
#                 'Year': '2002',
#                 'index': 56},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '57.2',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.59',
#                 'Year': '2003',
#                 'index': 57},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '57.1',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.59',
#                 'Year': '2004',
#                 'index': 58},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '56.9',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.59',
#                 'Year': '2005',
#                 'index': 59},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '57',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.59',
#                 'Year': '2006',
#                 'index': 60},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '54.7',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.59',
#                 'Year': '2007',
#                 'index': 61},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '54.2',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.58',
#                 'Year': '2008',
#                 'index': 62},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '51.4',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.58',
#                 'Year': '2009',
#                 'index': 63},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '49.1',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.58',
#                 'Year': '2010',
#                 'index': 64},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '47.9',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.58',
#                 'Year': '2011',
#                 'index': 65},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '47.8',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.58',
#                 'Year': '2012',
#                 'index': 66},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '48',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.59',
#                 'Year': '2013',
#                 'index': 67},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '77.2',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.33',
#                 'Year': '1980',
#                 'index': 68},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '77.3',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.33',
#                 'Year': '1981',
#                 'index': 69},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '77.1',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.33',
#                 'Year': '1982',
#                 'index': 70},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '77.2',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.33',
#                 'Year': '1983',
#                 'index': 71},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '77.6',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.33',
#                 'Year': '1984',
#                 'index': 72},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '78.2',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.33',
#                 'Year': '1985',
#                 'index': 73},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '78.9',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.33',
#                 'Year': '1986',
#                 'index': 74},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '78.9',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.33',
#                 'Year': '1987',
#                 'index': 75},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '78.7',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.34',
#                 'Year': '1988',
#                 'index': 76},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '78.7',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.34',
#                 'Year': '1989',
#                 'index': 77},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '77.8',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.34',
#                 'Year': '1990',
#                 'index': 78},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '76.7',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.35',
#                 'Year': '1991',
#                 'index': 79},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '77',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.35',
#                 'Year': '1992',
#                 'index': 80},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '77',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.35',
#                 'Year': '1993',
#                 'index': 81},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '77',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.35',
#                 'Year': '1994',
#                 'index': 82},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '76.6',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.36',
#                 'Year': '1995',
#                 'index': 83},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '76.8',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.36',
#                 'Year': '1996',
#                 'index': 84},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '77.6',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.36',
#                 'Year': '1997',
#                 'index': 85},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '77.5',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.35',
#                 'Year': '1998',
#                 'index': 86},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '77.5',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.35',
#                 'Year': '1999',
#                 'index': 87},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '77.8',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.35',
#                 'Year': '2000',
#                 'index': 88},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '77.1',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.34',
#                 'Year': '2001',
#                 'index': 89},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '76.4',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.34',
#                 'Year': '2002',
#                 'index': 90},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '75.4',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.34',
#                 'Year': '2003',
#                 'index': 91},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '75',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.34',
#                 'Year': '2004',
#                 'index': 92},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '74.6',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.34',
#                 'Year': '2005',
#                 'index': 93},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '74.6',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.34',
#                 'Year': '2006',
#                 'index': 94},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '74.4',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.34',
#                 'Year': '2007',
#                 'index': 95},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '74.4',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.34',
#                 'Year': '2008',
#                 'index': 96},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '72.9',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.35',
#                 'Year': '2009',
#                 'index': 97},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '71.4',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.35',
#                 'Year': '2010',
#                 'index': 98},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '71.3',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.35',
#                 'Year': '2011',
#                 'index': 99},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '70.9',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.35',
#                 'Year': '2012',
#                 'index': 100},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '70.7',
#                 'Race/ethnicity': None,
#                 'Sex': None,
#                 'Standard Error on Percentage': '0.35',
#                 'Year': '2013',
#                 'index': 101},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '81.7',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.36',
#                 'Year': '1980',
#                 'index': 102},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '81.2',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.36',
#                 'Year': '1981',
#                 'index': 103},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '80.1',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.37',
#                 'Year': '1982',
#                 'index': 104},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '80.3',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.37',
#                 'Year': '1983',
#                 'index': 105},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '80.5',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.37',
#                 'Year': '1984',
#                 'index': 106},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '80.7',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.37',
#                 'Year': '1985',
#                 'index': 107},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '81.1',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.38',
#                 'Year': '1986',
#                 'index': 108},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '80.3',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.39',
#                 'Year': '1987',
#                 'index': 109},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '80.2',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.39',
#                 'Year': '1988',
#                 'index': 110},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '80.6',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.39',
#                 'Year': '1989',
#                 'index': 111},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '79.4',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.39',
#                 'Year': '1990',
#                 'index': 112},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '78.5',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.39',
#                 'Year': '1991',
#                 'index': 113},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '78.6',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.4',
#                 'Year': '1992',
#                 'index': 114},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '78.3',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.4',
#                 'Year': '1993',
#                 'index': 115},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '78.1',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.4',
#                 'Year': '1994',
#                 'index': 116},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '78.2',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.41',
#                 'Year': '1995',
#                 'index': 117},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '77.4',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.41',
#                 'Year': '1996',
#                 'index': 118},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '76.9',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.41',
#                 'Year': '1997',
#                 'index': 119},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '76.6',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.41',
#                 'Year': '1998',
#                 'index': 120},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '76.4',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.41',
#                 'Year': '1999',
#                 'index': 121},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '77.2',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.4',
#                 'Year': '2000',
#                 'index': 122},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '75.9',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.4',
#                 'Year': '2001',
#                 'index': 123},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '74.9',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.41',
#                 'Year': '2002',
#                 'index': 124},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '74',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.41',
#                 'Year': '2003',
#                 'index': 125},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '73.7',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.41',
#                 'Year': '2004',
#                 'index': 126},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '73.3',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.41',
#                 'Year': '2005',
#                 'index': 127},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '73.8',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.41',
#                 'Year': '2006',
#                 'index': 128},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '72.1',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.41',
#                 'Year': '2007',
#                 'index': 129},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '72.1',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.41',
#                 'Year': '2008',
#                 'index': 130},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '69.3',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.42',
#                 'Year': '2009',
#                 'index': 131},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '67.6',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.42',
#                 'Year': '2010',
#                 'index': 132},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '67.5',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.42',
#                 'Year': '2011',
#                 'index': 133},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '67.4',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.42',
#                 'Year': '2012',
#                 'index': 134},
#                {'Age': '18-24',
#                 'Characteristic': 'Total - Male, Age 18-24',
#                 'Note on Percent': None,
#                 'Percentage': '67',
#                 'Race/ethnicity': None,
#                 'Sex': 'Male',
#                 'Standard Error on Percentage': '0.42',
#                 'Year': '2013',
#                 'index': 135},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Male, Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '71.3',
# ...
#                 'Note on Percent': None,
#                 'Percentage': '48.9',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '2.05',
#                 'Year': '2006',
#                 'index': 2216},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Female, Hispanic, Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '49.6',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.96',
#                 'Year': '2007',
#                 'index': 2217},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Female, Hispanic, Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '48.7',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.91',
#                 'Year': '2008',
#                 'index': 2218},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Female, Hispanic, Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '45.7',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.85',
#                 'Year': '2009',
#                 'index': 2219},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Female, Hispanic, Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '42.2',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.83',
#                 'Year': '2010',
#                 'index': 2220},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Female, Hispanic, Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '40.2',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.83',
#                 'Year': '2011',
#                 'index': 2221},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Female, Hispanic, Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '42.8',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.73',
#                 'Year': '2012',
#                 'index': 2222},
#                {'Age': '18-19',
#                 'Characteristic': 'Total - Female, Hispanic, Age 18-19',
#                 'Note on Percent': None,
#                 'Percentage': '42.1',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.71',
#                 'Year': '2013',
#                 'index': 2223},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '56.9',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.86',
#                 'Year': '1980',
#                 'index': 2224},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '59.9',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.8',
#                 'Year': '1981',
#                 'index': 2225},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '58.4',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.77',
#                 'Year': '1982',
#                 'index': 2226},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '56.5',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.75',
#                 'Year': '1983',
#                 'index': 2227},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '56.2',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.73',
#                 'Year': '1984',
#                 'index': 2228},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '57.7',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.71',
#                 'Year': '1985',
#                 'index': 2229},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '58.9',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.72',
#                 'Year': '1986',
#                 'index': 2230},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '60.4',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.68',
#                 'Year': '1987',
#                 'index': 2231},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '62.3',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.64',
#                 'Year': '1988',
#                 'index': 2232},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '60.7',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.66',
#                 'Year': '1989',
#                 'index': 2233},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '59.2',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.54',
#                 'Year': '1990',
#                 'index': 2234},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '56.4',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.54',
#                 'Year': '1991',
#                 'index': 2235},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '59.2',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.52',
#                 'Year': '1992',
#                 'index': 2236},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '56.2',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.51',
#                 'Year': '1993',
#                 'index': 2237},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '57.9',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.5',
#                 'Year': '1994',
#                 'index': 2238},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '55.9',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.5',
#                 'Year': '1995',
#                 'index': 2239},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '59.3',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.48',
#                 'Year': '1996',
#                 'index': 2240},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '62.2',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.47',
#                 'Year': '1997',
#                 'index': 2241},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '62.2',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.42',
#                 'Year': '1998',
#                 'index': 2242},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '63.1',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.4',
#                 'Year': '1999',
#                 'index': 2243},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '65',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.3',
#                 'Year': '2000',
#                 'index': 2244},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '64.5',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.26',
#                 'Year': '2001',
#                 'index': 2245},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '65',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.24',
#                 'Year': '2002',
#                 'index': 2246},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '63.3',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.25',
#                 'Year': '2003',
#                 'index': 2247},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '62.9',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.23',
#                 'Year': '2004',
#                 'index': 2248},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '59.4',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.25',
#                 'Year': '2005',
#                 'index': 2249},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '61.3',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.24',
#                 'Year': '2006',
#                 'index': 2250},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '63',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.21',
#                 'Year': '2007',
#                 'index': 2251},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '62.1',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.22',
#                 'Year': '2008',
#                 'index': 2252},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '63.2',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.2',
#                 'Year': '2009',
#                 'index': 2253},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '61.5',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.18',
#                 'Year': '2010',
#                 'index': 2254},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '63',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.15',
#                 'Year': '2011',
#                 'index': 2255},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '63.3',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.08',
#                 'Year': '2012',
#                 'index': 2256},
#                {'Age': '20-24',
#                 'Characteristic': 'Total - Female, Hispanic, Age 20-24',
#                 'Note on Percent': None,
#                 'Percentage': '64.3',
#                 'Race/ethnicity': 'Hispanic',
#                 'Sex': 'Female',
#                 'Standard Error on Percentage': '1.06',
#                 'Year': '2013',
#                 'index': 2257}]}

# %%
labour_len = len(labour_data['resources'])
labour_len
# Out:
# 1258

# %%
#column lists
labour_percentage = []
labour_year = []
labour_race = []
labour_sex = []

#for loop to create columns
for a in range(labour_len):
    labour_percentage.append(labour_data['resources'][a]['Percentage'])
    labour_year.append(int(labour_data['resources'][a]['Year']))
    labour_race.append(labour_data['resources'][a]['Race/ethnicity'])
    labour_sex.append(labour_data['resources'][a]['Sex'])
    
#dataframe

labour_race_df = pd.DataFrame({
    "Year" : labour_year,
    "Race" : labour_race,
    "Percentage" : labour_percentage
})

labour_sex_df = pd.DataFrame({
    "Year" : labour_year,
    "Sex" : labour_sex,
    "Percentage" : labour_percentage
})

labour_sex_df
#labour_df.sort_values(by=['Year', 'Race'], ascending=True)
# Out:
#       Year     Sex Percentage
# 0     1980    None       74.1
# 1     1981    None         74
# 2     1982    None       73.6
# 3     1983    None       73.7
# 4     1984    None       74.2
# 5     1985    None       74.8
# 6     1986    None       75.3
# 7     1987    None       75.1
# 8     1988    None         75
# 9     1989    None       74.9
# 10    1990    None       73.7
# 11    1991    None       72.8
# 12    1992    None       73.1
# 13    1993    None       73.1
# 14    1994    None         73
# 15    1995    None         73
# 16    1996    None       72.7
# 17    1997    None       73.1
# 18    1998    None       73.2
# 19    1999    None         73
# 20    2000    None       73.4
# 21    2001    None       72.3
# 22    2002    None       71.6
# 23    2003    None       70.4
# 24    2004    None       70.1
# 25    2005    None       69.8
# 26    2006    None       69.8
# 27    2007    None         69
# 28    2008    None       68.7
# 29    2009    None       66.8
# ...    ...     ...        ...
# 1228  1984  Female       56.2
# 1229  1985  Female       57.7
# 1230  1986  Female       58.9
# 1231  1987  Female       60.4
# 1232  1988  Female       62.3
# 1233  1989  Female       60.7
# 1234  1990  Female       59.2
# 1235  1991  Female       56.4
# 1236  1992  Female       59.2
# 1237  1993  Female       56.2
# 1238  1994  Female       57.9
# 1239  1995  Female       55.9
# 1240  1996  Female       59.3
# 1241  1997  Female       62.2
# 1242  1998  Female       62.2
# 1243  1999  Female       63.1
# 1244  2000  Female         65
# 1245  2001  Female       64.5
# 1246  2002  Female         65
# 1247  2003  Female       63.3
# 1248  2004  Female       62.9
# 1249  2005  Female       59.4
# 1250  2006  Female       61.3
# 1251  2007  Female         63
# 1252  2008  Female       62.1
# 1253  2009  Female       63.2
# 1254  2010  Female       61.5
# 1255  2011  Female         63
# 1256  2012  Female       63.3
# 1257  2013  Female       64.3
#
# [1258 rows x 3 columns]

# %%
#dropna for both dataframes

labour_race_df = labour_race_df.dropna(how='any')
labour_sex_df = labour_sex_df.dropna(how='any')

labour_race_df['Percentage'] = labour_race_df['Percentage'].astype(float)
labour_sex_df['Percentage'] = labour_sex_df['Percentage'].astype(float)

#labour_race_df
#labour_sex_df
# Out:
# C:\Users\Paola\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
#drop years 1980-1999

labour_race_df_2 = labour_race_df[labour_race_df['Year']>=2000]
#labour_race_df_2
labour_sex_df_2 = labour_sex_df[labour_sex_df['Year']>=2000]
#labour_sex_df_2

# %%
#replace Asian race to other
labour_race_df_2 = labour_race_df_2.replace(to_replace='Asian', value='Other')
#labour_race_df_2

# %%
#preliminary graph
#x axis = year
#y axis = percentage
#lines = race

labour_participation_race = pd.DataFrame(labour_race_df_2.groupby(['Year', 'Race'])['Percentage'].mean())
labour_participation_race.unstack(level=-1).plot(kind='line')

# %%
#graph
#x axis = year
#y axis = percentage
#lines = gender

labour_participation_sex = pd.DataFrame(labour_sex_df_2.groupby(['Year', 'Sex'])['Percentage'].mean())
labour_participation_sex.unstack(level=-1).plot(kind='line')

# %%
#export dataframes to excel
labour_participation_race.to_csv(r'C:\Users\Paola\Downloads\GroupProject_Team5-by-5-master\GroupProject_Team5-by-5-master\cleaning\Labour_Participation_Rate_by_Race.csv', index=None)
labour_participation_sex.to_csv(r'C:\Users\Paola\Downloads\GroupProject_Team5-by-5-master\GroupProject_Team5-by-5-master\cleaning\Labour_Participation_Rate_by_Gender.csv', index=None)
