# %%
import requests
import json
from pprint import pprint
import pandas as pd
import numpy as np
import os
import csv
import matplotlib.pyplot as plt

# %%
query_url = 'https://api.ed.gov/data/mbk-disconnected-youth?'
api_key = 'api_key=bVIf4sU0IzjYfs473ZQEyzOjmZ5hkWeG6vdk5vPc'
per_page = 'per_page=' + '360'
full_url = query_url + api_key + "&" + per_page

DY_data = requests.get(full_url).json()

pprint(DY_data)
# Out:
# {'pagination': {'count': 360, 'page': 1, 'pages': 1, 'per_page': 360},
#  'resources': [{'Characteristic': 'Total',
#                 'Count': '3676.6',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '13.9',
#                 'Race/ethnicity ': None,
#                 'Sex ': None,
#                 'Standard Error on Count': '83.9',
#                 'Standard Error on Percentage': '0.34',
#                 'Year': '2000',
#                 'index': 0},
#                {'Characteristic': 'Total',
#                 'Count': '3982.7',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '14.9',
#                 'Race/ethnicity ': None,
#                 'Sex ': None,
#                 'Standard Error on Count': '90',
#                 'Standard Error on Percentage': '0.38',
#                 'Year': '2001',
#                 'index': 1},
#                {'Characteristic': 'Total',
#                 'Count': '4383.7',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '16.1',
#                 'Race/ethnicity ': None,
#                 'Sex ': None,
#                 'Standard Error on Count': '92.1',
#                 'Standard Error on Percentage': '0.39',
#                 'Year': '2002',
#                 'index': 2},
#                {'Characteristic': 'Total',
#                 'Count': '4398.4',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '16',
#                 'Race/ethnicity ': None,
#                 'Sex ': None,
#                 'Standard Error on Count': '92.2',
#                 'Standard Error on Percentage': '0.38',
#                 'Year': '2003',
#                 'index': 3},
#                {'Characteristic': 'Total',
#                 'Count': '4303.5',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '15.5',
#                 'Race/ethnicity ': None,
#                 'Sex ': None,
#                 'Standard Error on Count': '91.7',
#                 'Standard Error on Percentage': '0.38',
#                 'Year': '2004',
#                 'index': 4},
#                {'Characteristic': 'Total',
#                 'Count': '4511.4',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '16.1',
#                 'Race/ethnicity ': None,
#                 'Sex ': None,
#                 'Standard Error on Count': '111.5',
#                 'Standard Error on Percentage': '0.4',
#                 'Year': '2005',
#                 'index': 5},
#                {'Characteristic': 'Total',
#                 'Count': '4249.9',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '15.2',
#                 'Race/ethnicity ': None,
#                 'Sex ': None,
#                 'Standard Error on Count': '95.9',
#                 'Standard Error on Percentage': '0.34',
#                 'Year': '2006',
#                 'index': 6},
#                {'Characteristic': 'Total',
#                 'Count': '4224.8',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '14.9',
#                 'Race/ethnicity ': None,
#                 'Sex ': None,
#                 'Standard Error on Count': '88.4',
#                 'Standard Error on Percentage': '0.31',
#                 'Year': '2007',
#                 'index': 7},
#                {'Characteristic': 'Total',
#                 'Count': '4363.6',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '15.4',
#                 'Race/ethnicity ': None,
#                 'Sex ': None,
#                 'Standard Error on Count': '89.3',
#                 'Standard Error on Percentage': '0.32',
#                 'Year': '2008',
#                 'index': 8},
#                {'Characteristic': 'Total',
#                 'Count': '5213.9',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '18.2',
#                 'Race/ethnicity ': None,
#                 'Sex ': None,
#                 'Standard Error on Count': '112.4',
#                 'Standard Error on Percentage': '0.39',
#                 'Year': '2009',
#                 'index': 9},
#                {'Characteristic': 'Total',
#                 'Count': '5623.7',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '19.2',
#                 'Race/ethnicity ': None,
#                 'Sex ': None,
#                 'Standard Error on Count': '117.4',
#                 'Standard Error on Percentage': '0.4',
#                 'Year': '2010',
#                 'index': 10},
#                {'Characteristic': 'Total',
#                 'Count': '5303.9',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '17.9',
#                 'Race/ethnicity ': None,
#                 'Sex ': None,
#                 'Standard Error on Count': '100.1',
#                 'Standard Error on Percentage': '0.34',
#                 'Year': '2011',
#                 'index': 11},
#                {'Characteristic': 'Total',
#                 'Count': '5067.5',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '16.8',
#                 'Race/ethnicity ': None,
#                 'Sex ': None,
#                 'Standard Error on Count': '107.3',
#                 'Standard Error on Percentage': '0.36',
#                 'Year': '2012',
#                 'index': 12},
#                {'Characteristic': 'Total',
#                 'Count': '5181.2',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '17.3',
#                 'Race/ethnicity ': None,
#                 'Sex ': None,
#                 'Standard Error on Count': '120.9',
#                 'Standard Error on Percentage': '0.4',
#                 'Year': '2013',
#                 'index': 13},
#                {'Characteristic': 'Total',
#                 'Count': '5131.4',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '17.1',
#                 'Race/ethnicity ': None,
#                 'Sex ': None,
#                 'Standard Error on Count': '132.9',
#                 'Standard Error on Percentage': '0.43',
#                 'Year': '2014',
#                 'index': 14},
#                {'Characteristic': 'Total - Male',
#                 'Count': '1416.5',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '10.7',
#                 'Race/ethnicity ': None,
#                 'Sex ': 'Male',
#                 'Standard Error on Count': '57.1',
#                 'Standard Error on Percentage': '0.43',
#                 'Year': '2000',
#                 'index': 15},
#                {'Characteristic': 'Total - Male',
#                 'Count': '1643.5',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '12.2',
#                 'Race/ethnicity ': None,
#                 'Sex ': 'Male',
#                 'Standard Error on Count': '65.4',
#                 'Standard Error on Percentage': '0.49',
#                 'Year': '2001',
#                 'index': 16},
#                {'Characteristic': 'Total - Male',
#                 'Count': '1889.8',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '13.8',
#                 'Race/ethnicity ': None,
#                 'Sex ': 'Male',
#                 'Standard Error on Count': '69.3',
#                 'Standard Error on Percentage': '0.51',
#                 'Year': '2002',
#                 'index': 17},
#                {'Characteristic': 'Total - Male',
#                 'Count': '1902.8',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '13.8',
#                 'Race/ethnicity ': None,
#                 'Sex ': 'Male',
#                 'Standard Error on Count': '69.5',
#                 'Standard Error on Percentage': '0.51',
#                 'Year': '2003',
#                 'index': 18},
#                {'Characteristic': 'Total - Male',
#                 'Count': '1845.7',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '13',
#                 'Race/ethnicity ': None,
#                 'Sex ': 'Male',
#                 'Standard Error on Count': '68.7',
#                 'Standard Error on Percentage': '0.49',
#                 'Year': '2004',
#                 'index': 19},
#                {'Characteristic': 'Total - Male',
#                 'Count': '1924.8',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '13.7',
#                 'Race/ethnicity ': None,
#                 'Sex ': 'Male',
#                 'Standard Error on Count': '71.9',
#                 'Standard Error on Percentage': '0.51',
#                 'Year': '2005',
#                 'index': 20},
#                {'Characteristic': 'Total - Male',
#                 'Count': '1758.7',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '12.5',
#                 'Race/ethnicity ': None,
#                 'Sex ': 'Male',
#                 'Standard Error on Count': '58.9',
#                 'Standard Error on Percentage': '0.41',
#                 'Year': '2006',
#                 'index': 21},
#                {'Characteristic': 'Total - Male',
#                 'Count': '1776.9',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '12.3',
#                 'Race/ethnicity ': None,
#                 'Sex ': 'Male',
#                 'Standard Error on Count': '58.3',
#                 'Standard Error on Percentage': '0.4',
#                 'Year': '2007',
#                 'index': 22},
#                {'Characteristic': 'Total - Male',
#                 'Count': '1831.3',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '12.7',
#                 'Race/ethnicity ': None,
#                 'Sex ': 'Male',
#                 'Standard Error on Count': '56.1',
#                 'Standard Error on Percentage': '0.39',
#                 'Year': '2008',
#                 'index': 23},
#                {'Characteristic': 'Total - Male',
#                 'Count': '2611.7',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '18',
#                 'Race/ethnicity ': None,
#                 'Sex ': 'Male',
#                 'Standard Error on Count': '76.1',
#                 'Standard Error on Percentage': '0.51',
#                 'Year': '2009',
#                 'index': 24},
#                {'Characteristic': 'Total - Male',
#                 'Count': '2753.7',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '18.6',
#                 'Race/ethnicity ': None,
#                 'Sex ': 'Male',
#                 'Standard Error on Count': '80.7',
#                 'Standard Error on Percentage': '0.54',
#                 'Year': '2010',
#                 'index': 25},
#                {'Characteristic': 'Total - Male',
#                 'Count': '2618.1',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '17.4',
#                 'Race/ethnicity ': None,
#                 'Sex ': 'Male',
#                 'Standard Error on Count': '71.1',
#                 'Standard Error on Percentage': '0.48',
#                 'Year': '2011',
#                 'index': 26},
#                {'Characteristic': 'Total - Male',
#                 'Count': '2385.4',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '15.7',
#                 'Race/ethnicity ': None,
#                 'Sex ': 'Male',
#                 'Standard Error on Count': '73.5',
#                 'Standard Error on Percentage': '0.49',
#                 'Year': '2012',
#                 'index': 27},
#                {'Characteristic': 'Total - Male',
#                 'Count': '2517.3',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '16.6',
#                 'Race/ethnicity ': None,
#                 'Sex ': 'Male',
#                 'Standard Error on Count': '78.6',
#                 'Standard Error on Percentage': '0.51',
#                 'Year': '2013',
#                 'index': 28},
#                {'Characteristic': 'Total - Male',
#                 'Count': '2452.5',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '16',
#                 'Race/ethnicity ': None,
#                 'Sex ': 'Male',
#                 'Standard Error on Count': '94.2',
#                 'Standard Error on Percentage': '0.61',
#                 'Year': '2014',
#                 'index': 29},
#                {'Characteristic': 'Total - Female',
#                 'Count': '2260',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '17.1',
#                 'Race/ethnicity ': None,
#                 'Sex ': 'Female',
#                 'Standard Error on Count': '69.8',
#                 'Standard Error on Percentage': '0.52',
#                 'Year': '2000',
#                 'index': 30},
#                {'Characteristic': 'Total - Female',
#                 'Count': '2339.2',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '17.5',
#                 'Race/ethnicity ': None,
#                 'Sex ': 'Female',
#                 'Standard Error on Count': '75.5',
#                 'Standard Error on Percentage': '0.57',
#                 'Year': '2001',
#                 'index': 31},
#                {'Characteristic': 'Total - Female',
#                 'Count': '2493.9',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '18.3',
#                 'Race/ethnicity ': None,
#                 'Sex ': 'Female',
#                 'Standard Error on Count': '77.3',
#                 'Standard Error on Percentage': '0.57',
#                 'Year': '2002',
#                 'index': 32},
#                {'Characteristic': 'Total - Female',
#                 'Count': '2495.6',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '18.3',
#                 'Race/ethnicity ': None,
#                 'Sex ': 'Female',
#                 'Standard Error on Count': '77.3',
#                 'Standard Error on Percentage': '0.58',
#                 'Year': '2003',
#                 'index': 33},
#                {'Characteristic': 'Total - Female',
#                 'Count': '2457.8',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '18',
#                 'Race/ethnicity ': None,
#                 'Sex ': 'Female',
#                 'Standard Error on Count': '76.9',
#                 'Standard Error on Percentage': '0.57',
#                 'Year': '2004',
#                 'index': 34},
#                {'Characteristic': 'Total - Female',
#                 'Count': '2586.6',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
# ...
#                 'index': 347},
#                {'Characteristic': 'Total - Female,Two or more races, '
#                                   'non-Hispanic',
#                 'Count': '43.1',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '18.1',
#                 'Race/ethnicity ': 'Two or more races, non-Hispanic',
#                 'Sex ': 'Female',
#                 'Standard Error on Count': '11.9',
#                 'Standard Error on Percentage': '4.54',
#                 'Year': '2003',
#                 'index': 348},
#                {'Characteristic': 'Total - Female,Two or more races, '
#                                   'non-Hispanic',
#                 'Count': '39.8',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '18.4',
#                 'Race/ethnicity ': 'Two or more races, non-Hispanic',
#                 'Sex ': 'Female',
#                 'Standard Error on Count': '11.4',
#                 'Standard Error on Percentage': '4.79',
#                 'Year': '2004',
#                 'index': 349},
#                {'Characteristic': 'Total - Female,Two or more races, '
#                                   'non-Hispanic',
#                 'Count': '42.9',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '16.6',
#                 'Race/ethnicity ': 'Two or more races, non-Hispanic',
#                 'Sex ': 'Female',
#                 'Standard Error on Count': '8.3',
#                 'Standard Error on Percentage': '3.16',
#                 'Year': '2005',
#                 'index': 350},
#                {'Characteristic': 'Total - Female,Two or more races, '
#                                   'non-Hispanic',
#                 'Count': '40.4',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '17.6',
#                 'Race/ethnicity ': 'Two or more races, non-Hispanic',
#                 'Sex ': 'Female',
#                 'Standard Error on Count': '6.5',
#                 'Standard Error on Percentage': '2.76',
#                 'Year': '2006',
#                 'index': 351},
#                {'Characteristic': 'Total - Female,Two or more races, '
#                                   'non-Hispanic',
#                 'Count': '40.3',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '15.9',
#                 'Race/ethnicity ': 'Two or more races, non-Hispanic',
#                 'Sex ': 'Female',
#                 'Standard Error on Count': '6.6',
#                 'Standard Error on Percentage': '2.58',
#                 'Year': '2007',
#                 'index': 352},
#                {'Characteristic': 'Total - Female,Two or more races, '
#                                   'non-Hispanic',
#                 'Count': '46.7',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '18.6',
#                 'Race/ethnicity ': 'Two or more races, non-Hispanic',
#                 'Sex ': 'Female',
#                 'Standard Error on Count': '10.5',
#                 'Standard Error on Percentage': '3.74',
#                 'Year': '2008',
#                 'index': 353},
#                {'Characteristic': 'Total - Female,Two or more races, '
#                                   'non-Hispanic',
#                 'Count': '39.1',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '15',
#                 'Race/ethnicity ': 'Two or more races, non-Hispanic',
#                 'Sex ': 'Female',
#                 'Standard Error on Count': '7.5',
#                 'Standard Error on Percentage': '2.82',
#                 'Year': '2010',
#                 'index': 355},
#                {'Characteristic': 'Total - Female,Two or more races, '
#                                   'non-Hispanic',
#                 'Count': '53.6',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '20.2',
#                 'Race/ethnicity ': 'Two or more races, non-Hispanic',
#                 'Sex ': 'Female',
#                 'Standard Error on Count': '9.8',
#                 'Standard Error on Percentage': '3.46',
#                 'Year': '2011',
#                 'index': 356},
#                {'Characteristic': 'Total - Female,Two or more races, '
#                                   'non-Hispanic',
#                 'Count': '73.5',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '19.4',
#                 'Race/ethnicity ': 'Two or more races, non-Hispanic',
#                 'Sex ': 'Female',
#                 'Standard Error on Count': '14.8',
#                 'Standard Error on Percentage': '3.69',
#                 'Year': '2012',
#                 'index': 357},
#                {'Characteristic': 'Total - Female,Two or more races, '
#                                   'non-Hispanic',
#                 'Count': '58.8',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '16.7',
#                 'Race/ethnicity ': 'Two or more races, non-Hispanic',
#                 'Sex ': 'Female',
#                 'Standard Error on Count': '11.5',
#                 'Standard Error on Percentage': '3.13',
#                 'Year': '2013',
#                 'index': 358},
#                {'Characteristic': 'Total - Female,Two or more races, '
#                                   'non-Hispanic',
#                 'Count': '51.7',
#                 'Note on Count': 'Data are based on samples surveys of the '
#                                  'civilian noninstitutional population. Race '
#                                  'categories exclude persons of Hispanic '
#                                  'ethnicity. Data for Pacific Islanders and '
#                                  'persons of two or more races collected '
#                                  'separately after 2002. Detail may not sum to '
#                                  'totals because of rounding.',
#                 'Note on Percent': 'Data are based on samples surveys of the '
#                                    'civilian noninstitutional population. Race '
#                                    'categories exclude persons of Hispanic '
#                                    'ethnicity. Data for Pacific Islanders and '
#                                    'persons of two or more races collected '
#                                    'separately after 2002.',
#                 'Percentage': '13.9',
#                 'Race/ethnicity ': 'Two or more races, non-Hispanic',
#                 'Sex ': 'Female',
#                 'Standard Error on Count': '11.6',
#                 'Standard Error on Percentage': '2.92',
#                 'Year': '2014',
#                 'index': 359}]}

# %%
length = len(DY_data['resources'])

# %%
#collect data for list
percentage=[]
year=[]
race=[]
sex=[]
count=[]
percentage=[]

for a in range(length):
    year.append(int(DY_data['resources'][a]['Year']))
    sex.append(DY_data['resources'][a]['Sex '])
    race.append(DY_data['resources'][a]['Race/ethnicity '])
    percentage.append(DY_data['resources'][a]['Percentage'])
    count.append(DY_data['resources'][a]['Count'])

# %%
disconnected_youth_race = pd.DataFrame({'Year': year, 'Race': race, 'Count': count, 'Percentage': percentage})

disconnected_youth_gender = pd.DataFrame({'Year': year, 'Sex': sex, 'Count': count, 'Percentage': percentage})

disconnected_youth_gender.head()
# Out:
#    Year   Sex   Count Percentage
# 0  2000  None  3676.6       13.9
# 1  2001  None  3982.7       14.9
# 2  2002  None  4383.7       16.1
# 3  2003  None  4398.4         16
# 4  2004  None  4303.5       15.5

# %%
#replace Race values to other
disconnected_youth_race_2 = disconnected_youth_race.replace(to_replace=['Asian, non-Hispanic', 'Pacific Islander, non-Hispanic','American Indian/Alaska Native, non-Hispanic', 'Two or more races, non-Hispanic'], value = 'Other')
disconnected_youth_race_3 = disconnected_youth_race_2.replace(to_replace=['White, non-Hispanic', 'Black, non-Hispanic'], value=['Caucasian', 'African-American'])
disconnected_youth_race_3['Race'].unique()
# Out:
# array([None, 'Caucasian', 'African-American', 'Hispanic', 'Other'],
#       dtype=object)

# %%
disconnected_youth_race_3
disconnected_youth_gender.head()
# Out:
#    Year   Sex   Count Percentage
# 0  2000  None  3676.6       13.9
# 1  2001  None  3982.7       14.9
# 2  2002  None  4383.7       16.1
# 3  2003  None  4398.4         16
# 4  2004  None  4303.5       15.5

# %%
#drop nones, convert percentage to float

disconnected_youth_race_3 = disconnected_youth_race_3.dropna(how='any')
disconnected_youth_gender = disconnected_youth_gender.dropna(how='any')

disconnected_youth_race_3['Percentage'] = disconnected_youth_race_3['Percentage'].astype(float)
disconnected_youth_race_3['Count'] = disconnected_youth_race_3['Count'].astype(float)
disconnected_youth_gender['Percentage'] = disconnected_youth_gender['Percentage'].astype(float)
disconnected_youth_gender['Count'] = disconnected_youth_gender['Count'].astype(float)

# %%
DY_gender = pd.DataFrame(disconnected_youth_gender.groupby(['Year', 'Sex'])['Count'].sum())
DY_gender.unstack(level=-1).plot(kind='line')

# %%
DY_gender1 = pd.DataFrame(disconnected_youth_gender.groupby(['Year', 'Sex'])['Percentage'].mean())
DY_gender1.unstack(level=-1).plot(kind='line')

# %%
DY_race = pd.DataFrame(disconnected_youth_race_3.groupby(['Year', 'Race'])['Count'].sum())
DY_race.unstack(level=-1).plot(kind='line')

# %%
DY_race1 = pd.DataFrame(disconnected_youth_race_3.groupby(['Year', 'Race'])['Percentage'].mean())
DY_race1.unstack(level=-1).plot(kind='line', legend=False)

# %%
#export dataframes to excel
disconnected_youth_race_3.to_csv(r'C:\Users\Paola\Downloads\GroupProject_Team5-by-5-master\GroupProject_Team5-by-5-master\cleaning\Disconnected_Youth_Rate_by_Race.csv', index=None)
disconnected_youth_gender.to_csv(r'C:\Users\Paola\Downloads\GroupProject_Team5-by-5-master\GroupProject_Team5-by-5-master\cleaning\Disconnected_Youth_Rate_by_Gender.csv', index=None)
