# %%
import pandas as pd
import plotly
import matplotlib.pyplot as plt
import plotly.plotly as py
import plotly.graph_objs as go
from scipy import stats
from numpy import arange,array,ones

plotly.tools.set_credentials_file(username = 'SheriffLobo', api_key = 'lsAcLHWwoJERarwJXuYq')

# %%
#overall datasets
imp_rate_df = pd.read_csv(r'C:\Users\Llobo\Documents\Data_analytics\GroupProject_Team5-by-5\CSVs\imprisonmentDf_totalImprisonmentsPerCapita_Percent.csv')
drop_total_rate_df = pd.read_csv(r'C:\Users\Llobo\Documents\Data_analytics\GroupProject_Team5-by-5\CSVs\Total_drop_out_rates_by_year.csv')

#Race datasets
drop_rate_race_df = pd.read_csv(r'C:\Users\Llobo\Documents\Data_analytics\GroupProject_Team5-by-5\CSVs\Total_drop_out_rates_by_year_and_race.csv')
imp_rate_race_df = pd.read_csv(r'C:\Users\Llobo\Documents\Data_analytics\GroupProject_Team5-by-5\CSVs\imprisonmentDf_perRace_perCapita.csv')
disco_rate_race_df = pd.read_csv(r'C:\Users\Llobo\Documents\Data_analytics\GroupProject_Team5-by-5\CSVs\Disconnected Youth Rate - RacePercentage by Year.csv')
labor_rate_race_df = pd.read_csv(r'C:\Users\Llobo\Documents\Data_analytics\GroupProject_Team5-by-5\CSVs\Labour Participation Rate - RacePercentage by Year.csv')

#Gender datasets
imp_rate_gender_df = pd.read_csv(r'C:\Users\Llobo\Documents\Data_analytics\GroupProject_Team5-by-5\CSVs\Imp_rates_by_gender.csv')
drop_rate_gender_df = pd.read_csv(r'C:\Users\Llobo\Documents\Data_analytics\GroupProject_Team5-by-5\CSVs\Drop_out_rates_by_gender_Laurel.csv')

# %%
#total dropout rate by year graph block

#traces
drop_trace = go.Scatter(
    x = drop_total_rate_df['Year'],
    y = drop_total_rate_df['Total']
)

data = [drop_trace]

#layout
layout = dict(title = 'Total high school dropout rate by year',
              xaxis = dict(title = 'Year'),
              yaxis = dict(title = 'Dropout rate (%)'),
              autosize = True
             )

#figure
fig = dict(data = data, layout = layout)

#generates the graph and opens
py.iplot(fig, filename='Total dropout rate by year.html')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~SheriffLobo/44.embed" height="525px" width="100%"></iframe>

# %%
#total imprisonment rate by year graph block
imp_rate_df
#traces
imp_trace = go.Scatter(
    x = imp_rate_df['Year'],
    y = imp_rate_df['Per Capita Rate per 100,000']
)

data = [imp_trace]

#layout
layout = dict(title = 'Total imprisonment rate by year',
              xaxis = dict(title = 'Year'),
              yaxis = dict(title = 'Imprisonment rate (%)'),
              autosize = True
             )

#figure
fig = dict(data = data, layout = layout)

#generates url for the graph and opens
url = py.iplot(fig, filename='Total Imprisonment rate by year.html')
print(url)
# Out:
# <plotly.tools.PlotlyDisplay object>

# %%
#Dropout rate vs imprisonment regression graph block

xi = drop_total_rate_df['Total']
y = imp_rate_df['Per Capita Rate per 100,000']

#generate linear fit
slope, intercept, r_value, p_value, std_err = stats.linregress(xi,y)
line = slope*xi + intercept
r_value = round(r_value, 3)

#data
drop_imp_trace = go.Scatter(
    x = drop_total_rate_df['Total'],
    y = imp_rate_df['Per Capita Rate per 100,000'],
    mode = 'markers'
)

fit_line = go.Scatter(
    x = xi,
    y = line,
    mode = 'lines'
)

data = [drop_imp_trace, fit_line]

#annotation

annotation = go.Annotation(
                  x=22.5,
                  y=20,
                  text= f"R^2 = {r_value}",
                  showarrow=False,
                  font=go.Font(size=12)
                  )


#layout
layout = dict(title = 'High school dropout vs. Imprisonment',
              xaxis = dict(title = 'High school dropout rate (%)'),
              yaxis = dict(title = 'Imprisonment rate (%)'),
              showlegend = False,
              annotations = [annotation],
              autosize = True
             )

#figure
fig = go.Figure(data = data, layout = layout)

#generates url for the graph and opens
py.iplot(fig, filename='School dropout vs Imprisonment_Final.html')
# Out:
# C:\Users\Llobo\Anaconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:318: DeprecationWarning:
#
# plotly.graph_objs.Font is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.Font
#   - plotly.graph_objs.layout.hoverlabel.Font
#   - etc.
#
#
# C:\Users\Llobo\Anaconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:144: DeprecationWarning:
#
# plotly.graph_objs.Annotation is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.Annotation
#   - plotly.graph_objs.layout.scene.Annotation
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~SheriffLobo/48.embed" height="525px" width="100%"></iframe>

# %%
# High school dropout vs. imprisonment by race

#Df transformation
imp_rate_race_df2 = pd.DataFrame({'Year': imp_rate_race_df['Year'],
                                 'African American': [x/1000 for x in imp_rate_race_df['African American']],
                                 'Caucasian': [x/1000 for x in imp_rate_race_df['Caucasian']],
                                 'Hispanic': [x/1000 for x in imp_rate_race_df['Hispanic']],
                                 'Other': [x/1000 for x in imp_rate_race_df['Other']]})

#STATS###########################################################################################################################

##African American stats
x0 = drop_rate_race_df['Dropout Black']
y0 = imp_rate_race_df2['African American']

###generate linear fit parameters
slope0, intercept0, r_value0, p_value0, std_err0 = stats.linregress(x0,y0)
line0 = slope0*x0 + intercept0
r_sq0 = round((r_value0**2), 2)

##Caucasian stats
x1 = drop_rate_race_df['Dropout White']
y1 = imp_rate_race_df2['Caucasian']

###generate linear fit parameters
slope1, intercept1, r_value1, p_value1, std_err1 = stats.linregress(x1,y1)
line1 = slope1*x1 + intercept1
r_sq1 = round((r_value1**2), 2)

##Hispanic stats
x2 = drop_rate_race_df['Dropout Hispanic']
y2 = imp_rate_race_df2['Hispanic']

###generate linear fit parameters
slope2, intercept2, r_value2, p_value2, std_err2 = stats.linregress(x2,y2)
line2 = slope2*x2 + intercept2
r_sq2 = round((r_value2**2), 2)

##Other stats
x3 = drop_rate_race_df['Dropout other']
y3 = imp_rate_race_df2['Other']

###generate linear fit parameters
slope3, intercept3, r_value3, p_value3, std_err3 = stats.linregress(x3,y3)
line3 = slope3*x3 + intercept3
r_sq3 = round((r_value3**2), 2)

#################################################################################################################################

#DATA

##African American data and line

AA_trace = go.Scatter(
    x = drop_rate_race_df['Dropout Black'],
    y = imp_rate_race_df2['African American'],
    mode = 'markers',
    visible = False,
    line=dict(color='#4b5320')
)

AA_line = go.Scatter(
    x = x0,
    y = line0, 
    visible = False,
    mode = 'lines'
)

##Caucasian data and line

CA_trace = go.Scatter(
    x = drop_rate_race_df['Dropout White'],
    y = imp_rate_race_df2['Caucasian'],
    mode = 'markers',
    visible = False,
    line=dict(color='#4b5320')
)

CA_line = go.Scatter(
    x = x1,
    y = line1, 
    visible = False,
    mode = 'lines'
)

##Hispanic data and line

HI_trace = go.Scatter(
    x = drop_rate_race_df['Dropout Hispanic'],
    y = imp_rate_race_df2['Hispanic'],
    mode = 'markers',
    visible = False,
    line=dict(color='#4b5320')
)

HI_line = go.Scatter(
    x = x2,
    y = line2, 
    visible = False,
    mode = 'lines'
)

##Other data and line

OT_trace = go.Scatter(
    x = drop_rate_race_df['Dropout other'],
    y = imp_rate_race_df2['Other'],
    mode = 'markers',
    visible = False,
    line=dict(color='#4b5320')
)

OT_line = go.Scatter(
    x = x3,
    y = line3, 
    visible = False,
    mode = 'lines'
)

data = [AA_trace, AA_line, CA_trace, CA_line, HI_trace, HI_line, OT_trace, OT_line]

#################################################################################################################################

#ANNOTATIONS

##African american annotation
AA_anno = [dict(x=25,
                y=8,
                text=f"R^2 = {r_sq0}",
                showarrow = False,
                font = go.Font(size=12))]

##Caucasian annotation
CA_anno = [dict(x=17,
                y=2,
                text=f"R^2 = {r_sq1}",
                showarrow = False,
                font = go.Font(size=12))]

##Hispanic annotation
HI_anno = [dict(x=35,
                y=3.5,
                text=f"R^2 = {r_sq2}",
                showarrow = False,
                font = go.Font(size=12))]

##Other annotation
OT_anno = [dict(x=22.55,
                y=3,
                text=f"R^2 = {r_sq3}",
                showarrow = False,
                font = go.Font(size=12))]

#################################################################################################################################

#MENU
updatemenus = list([
    dict(active=-1,
         buttons=list([   
            dict(label = 'African American',
                 method = 'update',
                 args = [{'visible': [True, True, False, False, False, False, False, False]},
                         {'title': 'Imprisonment vs. Dropout Rate by Race',
                          'annotations': AA_anno}]),
             dict(label = 'Caucasian',
                 method = 'update',
                 args = [{'visible': [False, False, True, True, False, False, False, False]},
                         {'title': 'Imprisonment vs. Dropout Rate by Race',
                          'annotations': CA_anno}]),
             dict(label = 'Hispanic',
                 method = 'update',
                 args = [{'visible': [False, False, False, False, True, True, False, False]},
                         {'title': 'Imprisonment vs. Dropout Rate by Race',
                          'annotations': HI_anno}]),
             dict(label = 'Other',
                 method = 'update',
                 args = [{'visible': [False, False, False, False, False, False, True, True]},
                         {'title': 'Imprisonment vs. Dropout Rate by Race',
                          'annotations': OT_anno}]),
             dict(label = 'Reset',
                 method = 'update',
                 args = [{'visible': [False, False, False, False, False, False, False, False]},
                         {'title': 'Imprisonment vs. Dropout Rate by Race',
                          'annotations': []}])]))])

#################################################################################################################################
#layout

layout = dict(title='Imprisonment vs. Dropout Rate by Race', showlegend=False,
              updatemenus=updatemenus,
              xaxis = dict(title = 'High school dropout rate (%)'),
              yaxis = dict(title = 'Imprisonment rate (%)'),
              autosize = True)

#################################################################################################################################

#figure config
fig = dict(data = data, layout = layout)

#plot
py.iplot(fig, filename = 'Imprisonment rate vs. Dropout Rate by Race')
# Out:
# C:\Users\Llobo\Anaconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:318: DeprecationWarning:
#
# plotly.graph_objs.Font is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.Font
#   - plotly.graph_objs.layout.hoverlabel.Font
#   - etc.
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~SheriffLobo/50.embed" height="525px" width="100%"></iframe>

# %%
#Dropout rate vs imprisonment rate by gender


#STATS###########################################################################################################################

##Male stats
x0 = drop_rate_gender_df['Male dropout %']
y0 = imp_rate_gender_df['Male imp %']

###generate linear fit parameters
slope0, intercept0, r_value0, p_value0, std_err0 = stats.linregress(x0,y0)
line0 = slope0*x0 + intercept0
r_sq0 = round((r_value0**2), 2)

##Female stats
x1 = drop_rate_gender_df['Female dropout %']
y1 = imp_rate_gender_df['Female imp %']

###generate linear fit parameters
slope1, intercept1, r_value1, p_value1, std_err1 = stats.linregress(x1,y1)
line1 = slope1*x1 + intercept1
r_sq1 = round((r_value1**2), 2)


#################################################################################################################################

#DATA

##Male data and line

MA_trace = go.Scatter(
    x = x0,
    y = y0,
    mode = 'markers',
    visible = False,
    line=dict(color='#4b5320')
)

MA_line = go.Scatter(
    x = x0,
    y = line0, 
    visible = False,
    mode = 'lines'
)

##Female data and line

FA_trace = go.Scatter(
    x = x1,
    y = y1,
    mode = 'markers',
    visible = False,
    line=dict(color='#4b5320')
)

FA_line = go.Scatter(
    x = x1,
    y = line1, 
    visible = False,
    mode = 'lines'
)


data = [MA_trace, MA_line, FA_trace, FA_line]

#################################################################################################################################

#ANNOTATIONS

##Male annotation
MA_anno = [dict(x=23,
                y=1.7,
                text=f"R^2 = {r_sq0}",
                showarrow = False,
                font = go.Font(size=12))]

##Female annotation
FA_anno = [dict(x=19,
                y=0.4,
                text=f"R^2 = {r_sq1}",
                showarrow = False,
                font = go.Font(size=12))]

#################################################################################################################################

#MENU
updatemenus = list([
    dict(active=-1,
         buttons=list([   
            dict(label = 'Male',
                 method = 'update',
                 args = [{'visible': [True, True, False, False]},
                         {'title': 'Imprisonment vs. Dropout Rate by Sex',
                          'annotations': MA_anno}]),
             dict(label = 'Female',
                 method = 'update',
                 args = [{'visible': [False, False, True, True]},
                         {'title': 'Imprisonment vs. Dropout Rate by Sex',
                          'annotations': FA_anno}]),
             dict(label = 'Reset',
                 method = 'update',
                 args = [{'visible': [False, False, False, False]},
                         {'title': 'Imprisonment vs. Dropout Rate by Sex',
                          'annotations': []}])]))])

#################################################################################################################################
#layout

layout = dict(title='Imprisonment vs. Dropout Rate by Sex', showlegend=False,
              updatemenus=updatemenus,
              xaxis = dict(title = 'High school dropout rate (%)'),
              yaxis = dict(title = 'Imprisonment rate (%)'),
              autosize = True)

#################################################################################################################################

#figure config
fig = dict(data = data, layout = layout)

#plot
py.iplot(fig, filename = 'Imprisonment rate vs. Dropout Rate by Sex')
# Out:
# C:\Users\Llobo\Anaconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:318: DeprecationWarning:
#
# plotly.graph_objs.Font is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.Font
#   - plotly.graph_objs.layout.hoverlabel.Font
#   - etc.
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~SheriffLobo/52.embed" height="525px" width="100%"></iframe>

# %%
# Disconnected youth vs imprisonment by race


#DF manipulation
disco_rate_race_df2 = disco_rate_race_df.loc[:12, :]

#STATS###########################################################################################################################

##African American stats
x0 = disco_rate_race_df2['African-American']
y0 = imp_rate_race_df2['African American']

###generate linear fit parameters
slope0, intercept0, r_value0, p_value0, std_err0 = stats.linregress(x0,y0)
line0 = slope0*x0 + intercept0
r_sq0 = round((r_value0**2), 2)

##Caucasian stats
x1 = disco_rate_race_df2['Caucasian']
y1 = imp_rate_race_df2['Caucasian']

###generate linear fit parameters
slope1, intercept1, r_value1, p_value1, std_err1 = stats.linregress(x1,y1)
line1 = slope1*x1 + intercept1
r_sq1 = round((r_value1**2), 2)

##Hispanic stats
x2 = disco_rate_race_df2['Hispanic']
y2 = imp_rate_race_df2['Hispanic']

###generate linear fit parameters
slope2, intercept2, r_value2, p_value2, std_err2 = stats.linregress(x2,y2)
line2 = slope2*x2 + intercept2
r_sq2 = round((r_value2**2), 2)

##Other stats
x3 = disco_rate_race_df2['Other']
y3 = imp_rate_race_df2['Other']

###generate linear fit parameters
slope3, intercept3, r_value3, p_value3, std_err3 = stats.linregress(x3,y3)
line3 = slope3*x3 + intercept3
r_sq3 = round((r_value3**2), 2)

#################################################################################################################################

#DATA

##African American data and line

AA_trace = go.Scatter(
    x = x0,
    y = y0,
    mode = 'markers',
    visible = False,
    line=dict(color='#4b5320')
)

AA_line = go.Scatter(
    x = x0,
    y = line0, 
    visible = False,
    mode = 'lines'
)

##Caucasian data and line

CA_trace = go.Scatter(
    x = x1,
    y = y1,
    mode = 'markers',
    visible = False,
    line=dict(color='#4b5320')
)

CA_line = go.Scatter(
    x = x1,
    y = line1, 
    visible = False,
    mode = 'lines'
)

##Hispanic data and line

HI_trace = go.Scatter(
    x = x2,
    y = y2,
    mode = 'markers',
    visible = False,
    line=dict(color='#4b5320')
)

HI_line = go.Scatter(
    x = x2,
    y = line2, 
    visible = False,
    mode = 'lines'
)

##Other data and line

OT_trace = go.Scatter(
    x = x3,
    y = y3,
    mode = 'markers',
    visible = False,
    line=dict(color='#4b5320')
)

OT_line = go.Scatter(
    x = x3,
    y = line3, 
    visible = False,
    mode = 'lines'
)

data = [AA_trace, AA_line, CA_trace, CA_line, HI_trace, HI_line, OT_trace, OT_line]

#################################################################################################################################

#ANNOTATIONS

##African american annotation
AA_anno = [dict(x=25,
                y=8,
                text=f"R^2 = {r_sq0}",
                showarrow = False,
                font = go.Font(size=12))]

##Caucasian annotation
CA_anno = [dict(x=12,
                y=1.4,
                text=f"R^2 = {r_sq1}",
                showarrow = False,
                font = go.Font(size=12))]

##Hispanic annotation
HI_anno = [dict(x=22,
                y=3.5,
                text=f"R^2 = {r_sq2}",
                showarrow = False,
                font = go.Font(size=12))]

##Other annotation
OT_anno = [dict(x=22.55,
                y=3,
                text=f"R^2 = {r_sq3}",
                showarrow = False,
                font = go.Font(size=12))]

#################################################################################################################################

#MENU
updatemenus = list([
    dict(active=-1,
         buttons=list([   
            dict(label = 'African American',
                 method = 'update',
                 args = [{'visible': [True, True, False, False, False, False, False, False]},
                         {'title': 'Rate of disconnected youth vs. Imprisonment Rate by Race',
                          'annotations': AA_anno}]),
             dict(label = 'Caucasian',
                 method = 'update',
                 args = [{'visible': [False, False, True, True, False, False, False, False]},
                         {'title': 'Rate of disconnected youth vs. Imprisonment Rate by Race',
                          'annotations': CA_anno}]),
             dict(label = 'Hispanic',
                 method = 'update',
                 args = [{'visible': [False, False, False, False, True, True, False, False]},
                         {'title': 'Rate of disconnected youth vs. Imprisonment Rate by Race',
                          'annotations': HI_anno}]),
             dict(label = 'Other',
                 method = 'update',
                 args = [{'visible': [False, False, False, False, False, False, True, True]},
                         {'title': 'Rate of disconnected youth vs. Imprisonment Rate by Race',
                          'annotations': OT_anno}]),
             dict(label = 'Reset',
                 method = 'update',
                 args = [{'visible': [False, False, False, False, False, False, False, False]},
                         {'title': 'Rate of disconnected youth vs. Imprisonment Rate by Race',
                          'annotations': []}])]))])

#################################################################################################################################
#layout

layout = dict(title='Rate of disconnected youth vs. Imprisonment Rate by Race', showlegend=False,
              updatemenus=updatemenus,
              xaxis = dict(title = 'Disconnected youth rate (%)'),
              yaxis = dict(title = 'Imprisonment rate (%)'),
              autosize = True)

#################################################################################################################################

#figure config
fig = dict(data = data, layout = layout)

#plot
py.iplot(fig, filename = 'Rate of disconnected youth vs. Imprisonment Rate by Race')
# Out:
# C:\Users\Llobo\Anaconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:318: DeprecationWarning:
#
# plotly.graph_objs.Font is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.Font
#   - plotly.graph_objs.layout.hoverlabel.Font
#   - etc.
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~SheriffLobo/54.embed" height="525px" width="100%"></iframe>

# %%
#Labor participation rate vs Disconnected youth rate

#DF manipulation

labor_rate_race_df2 = labor_rate_race_df.loc[:12, :]

#STATS###########################################################################################################################

##African American stats
x0 = disco_rate_race_df2['African-American']
y0 = labor_rate_race_df2['African-American']

###generate linear fit parameters
slope0, intercept0, r_value0, p_value0, std_err0 = stats.linregress(x0,y0)
line0 = slope0*x0 + intercept0
r_sq0 = round((r_value0**2), 2)

##Caucasian stats
x1 = disco_rate_race_df2['Caucasian']
y1 = labor_rate_race_df2['Caucasian']

###generate linear fit parameters
slope1, intercept1, r_value1, p_value1, std_err1 = stats.linregress(x1,y1)
line1 = slope1*x1 + intercept1
r_sq1 = round((r_value1**2), 2)

##Hispanic stats
x2 = disco_rate_race_df2['Hispanic']
y2 = labor_rate_race_df2['Hispanic']

###generate linear fit parameters
slope2, intercept2, r_value2, p_value2, std_err2 = stats.linregress(x2,y2)
line2 = slope2*x2 + intercept2
r_sq2 = round((r_value2**2), 2)

##Other stats
x3 = disco_rate_race_df2['Other']
y3 = labor_rate_race_df2['Other']

###generate linear fit parameters
slope3, intercept3, r_value3, p_value3, std_err3 = stats.linregress(x3,y3)
line3 = slope3*x3 + intercept3
r_sq3 = round((r_value3**2), 2)

#################################################################################################################################

#DATA

##African American data and line

AA_trace = go.Scatter(
    x = x0,
    y = y0,
    mode = 'markers',
    visible = False,
    line=dict(color='#4b5320')
)

AA_line = go.Scatter(
    x = x0,
    y = line0, 
    visible = False,
    mode = 'lines'
)

##Caucasian data and line

CA_trace = go.Scatter(
    x = x1,
    y = y1,
    mode = 'markers',
    visible = False,
    line=dict(color='#4b5320')
)

CA_line = go.Scatter(
    x = x1,
    y = line1, 
    visible = False,
    mode = 'lines'
)

##Hispanic data and line

HI_trace = go.Scatter(
    x = x2,
    y = y2,
    mode = 'markers',
    visible = False,
    line=dict(color='#4b5320')
)

HI_line = go.Scatter(
    x = x2,
    y = line2, 
    visible = False,
    mode = 'lines'
)

##Other data and line

OT_trace = go.Scatter(
    x = x3,
    y = y3,
    mode = 'markers',
    visible = False,
    line=dict(color='#4b5320')
)

OT_line = go.Scatter(
    x = x3,
    y = line3, 
    visible = False,
    mode = 'lines'
)

data = [AA_trace, AA_line, CA_trace, CA_line, HI_trace, HI_line, OT_trace, OT_line]

#################################################################################################################################

#ANNOTATIONS

##African american annotation
AA_anno = [dict(x=27,
                y=65,
                text=f"R^2 = {r_sq0}",
                showarrow = False,
                font = go.Font(size=12))]

##Caucasian annotation
CA_anno = [dict(x=15,
                y=73,
                text=f"R^2 = {r_sq1}",
                showarrow = False,
                font = go.Font(size=12))]

##Hispanic annotation
HI_anno = [dict(x=24,
                y=68,
                text=f"R^2 = {r_sq2}",
                showarrow = False,
                font = go.Font(size=12))]

##Other annotation
OT_anno = [dict(x=24,
                y=56,
                text=f"R^2 = {r_sq3}",
                showarrow = False,
                font = go.Font(size=12))]

#################################################################################################################################

#MENU
updatemenus = list([
    dict(active=-1,
         buttons=list([   
            dict(label = 'African American',
                 method = 'update',
                 args = [{'visible': [True, True, False, False, False, False, False, False]},
                         {'title': 'Rate of disconnected youth vs. Labor participation Rate',
                          'annotations': AA_anno}]),
             dict(label = 'Caucasian',
                 method = 'update',
                 args = [{'visible': [False, False, True, True, False, False, False, False]},
                         {'title': 'Rate of disconnected youth vs. Labor participation Rate',
                          'annotations': CA_anno}]),
             dict(label = 'Hispanic',
                 method = 'update',
                 args = [{'visible': [False, False, False, False, True, True, False, False]},
                         {'title': 'Rate of disconnected youth vs. Labor participation Rate',
                          'annotations': HI_anno}]),
             dict(label = 'Other',
                 method = 'update',
                 args = [{'visible': [False, False, False, False, False, False, True, True]},
                         {'title': 'Rate of disconnected youth vs. Labor participation Rate',
                          'annotations': OT_anno}]),
             dict(label = 'Reset',
                 method = 'update',
                 args = [{'visible': [False, False, False, False, False, False, False, False]},
                         {'title': 'Rate of disconnected youth vs. Labor participation Rate',
                          'annotations': []}])]))])

#################################################################################################################################
#layout

layout = dict(title='Rate of disconnected youth vs. Labor participation Rate by Race', showlegend=False,
              updatemenus=updatemenus,
              xaxis = dict(title = 'Disconnected youth rate (%)'),
              yaxis = dict(title = 'Labor Participation rate (%)'),
              autosize = True)

#################################################################################################################################

#figure config
fig = dict(data = data, layout = layout)

#plot
py.iplot(fig, filename = 'Rate of disconnected youth vs. Labor participation Rate by Race')
# Out:
# C:\Users\Llobo\Anaconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:318: DeprecationWarning:
#
# plotly.graph_objs.Font is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.Font
#   - plotly.graph_objs.layout.hoverlabel.Font
#   - etc.
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~SheriffLobo/56.embed" height="525px" width="100%"></iframe>

# %%
#2008 pivot

#DF manipulation

##imprisonment df
imp_rate_2007_df = imp_rate_df.loc[:7, :]
imp_rate_2008on_df = imp_rate_df.loc[8:, :]

##dropout df
drop_rate_2007_df = drop_total_rate_df.loc[:7, :]
drop_rate_2008on_df = drop_total_rate_df.loc[8:, :]

#STATS###########################################################################################################################

##2000-2007 stats
x0 = drop_rate_2007_df['Total']
y0 = imp_rate_2007_df['Per Capita Rate per 100,000']

###generate linear fit parameters
slope0, intercept0, r_value0, p_value0, std_err0 = stats.linregress(x0,y0)
line0 = slope0*x0 + intercept0
r_sq0 = round((r_value0**2), 2)

##2008+ stats
x1 = drop_rate_2008on_df['Total']
y1 = imp_rate_2008on_df['Per Capita Rate per 100,000']

###generate linear fit parameters
slope1, intercept1, r_value1, p_value1, std_err1 = stats.linregress(x1,y1)
line1 = slope1*x1 + intercept1
r_sq1 = round((r_value1**2), 2)


#################################################################################################################################

#DATA

##2000-2007 data and line

MI_trace = go.Scatter(
    x = x0,
    y = y0,
    mode = 'markers',
    visible = False,
    line=dict(color='#4b5320')
)

MI_line = go.Scatter(
    x = x0,
    y = line0, 
    visible = False,
    mode = 'lines'
)

##2008+ data and line

FI_trace = go.Scatter(
    x = x1,
    y = y1,
    mode = 'markers',
    visible = False,
    line=dict(color='#4b5320')
)

FI_line = go.Scatter(
    x = x1,
    y = line1, 
    visible = False,
    mode = 'lines'
)


data = [MI_trace, MI_line, FI_trace, FI_line]

#################################################################################################################################

#ANNOTATIONS

##2000-2007 annotation
MI_anno = [dict(x=22.5,
                y=18,
                text=f"R^2 = {r_sq0}",
                showarrow = False,
                font = go.Font(size=12))]

##2008+ annotation
FI_anno = [dict(x=19.4,
                y=15,
                text=f"R^2 = {r_sq1}",
                showarrow = False,
                font = go.Font(size=12))]

#################################################################################################################################

#MENU
updatemenus = list([
    dict(active=-1,
         buttons=list([   
            dict(label = '2000-2007',
                 method = 'update',
                 args = [{'visible': [True, True, False, False]},
                         {'title': 'Imprisonment vs. Dropout Rate',
                          'annotations': MI_anno}]),
             dict(label = '2008-2012',
                 method = 'update',
                 args = [{'visible': [False, False, True, True]},
                         {'title': 'Imprisonment vs. Dropout Rate',
                          'annotations': FI_anno}]),
             dict(label = 'Reset',
                 method = 'update',
                 args = [{'visible': [False, False, False, False]},
                         {'title': 'Imprisonment vs. Dropout Rate',
                          'annotations': []}])]))])

#################################################################################################################################
#layout

layout = dict(title='Imprisonment vs. Dropout Rate', showlegend=False,
              updatemenus=updatemenus,
              xaxis = dict(title = 'High school dropout rate (%)'),
              yaxis = dict(title = 'Imprisonment rate (%)'),
              autosize = True)

#################################################################################################################################

#figure config
fig = dict(data = data, layout = layout)

#plot
py.iplot(fig, filename = '2008 Imprisonment rate vs. Dropout Rate')
# Out:
# C:\Users\Llobo\Anaconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:318: DeprecationWarning:
#
# plotly.graph_objs.Font is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.Font
#   - plotly.graph_objs.layout.hoverlabel.Font
#   - etc.
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~SheriffLobo/58.embed" height="525px" width="100%"></iframe>
