# %%
import requests
import json
from pprint import pprint

Imprisonment_baseUrl = "https://api.ed.gov/data/mbk-imprisonment?"
Imprisonment_apiKey = "api_key=DTeVODnGRjLME8jd6PQCOy1DpgLqXPdHWtGO4EqA"
Imprisonment_perPage = "per_page=" + "4000"
Imprisonment_url = baseUrl + apiKey + "&" + perPage

ImprisonmentData = requests.get(url).json()

Imprisonment_length = len(ImprisonmentData["resources"])
Imprisonment_length

#pprint(ImprisonmentData["resources"][0]["Race/ethnicity"])
pprint(ImprisonmentData)
# Out:
# {'pagination': {'count': 195, 'page': 1, 'pages': 1, 'per_page': 4000},
#  'resources': [{'Characteristic': 'Total',
#                 'Count': '218896',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '791',
#                 'Sex': None,
#                 'Year': '2000',
#                 'index': 0},
#                {'Characteristic': 'Total',
#                 'Count': '219439',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '777',
#                 'Sex': None,
#                 'Year': '2001',
#                 'index': 1},
#                {'Characteristic': 'Total',
#                 'Count': '220072',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '766',
#                 'Sex': None,
#                 'Year': '2002',
#                 'index': 2},
#                {'Characteristic': 'Total',
#                 'Count': '218436',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '750',
#                 'Sex': None,
#                 'Year': '2003',
#                 'index': 3},
#                {'Characteristic': 'Total',
#                 'Count': '207416',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '707',
#                 'Sex': None,
#                 'Year': '2004',
#                 'index': 4},
#                {'Characteristic': 'Total',
#                 'Count': '200050',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '680',
#                 'Sex': None,
#                 'Year': '2005',
#                 'index': 5},
#                {'Characteristic': 'Total',
#                 'Count': '196234',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '663',
#                 'Sex': None,
#                 'Year': '2006',
#                 'index': 6},
#                {'Characteristic': 'Total',
#                 'Count': '197731',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '662',
#                 'Sex': None,
#                 'Year': '2007',
#                 'index': 7},
#                {'Characteristic': 'Total',
#                 'Count': '199105',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '658',
#                 'Sex': None,
#                 'Year': '2008',
#                 'index': 8},
#                {'Characteristic': 'Total',
#                 'Count': '201325',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '660',
#                 'Sex': None,
#                 'Year': '2009',
#                 'index': 9},
#                {'Characteristic': 'Total',
#                 'Count': '198997',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '644',
#                 'Sex': None,
#                 'Year': '2010',
#                 'index': 10},
#                {'Characteristic': 'Total',
#                 'Count': '192248',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '616',
#                 'Sex': None,
#                 'Year': '2011',
#                 'index': 11},
#                {'Characteristic': 'Total',
#                 'Count': '180734',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '575',
#                 'Sex': None,
#                 'Year': '2012',
#                 'index': 12},
#                {'Characteristic': 'Total - Male',
#                 'Count': '209543',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '1478',
#                 'Sex': 'Male',
#                 'Year': '2000',
#                 'index': 13},
#                {'Characteristic': 'Total - Male',
#                 'Count': '209658',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '1447',
#                 'Sex': 'Male',
#                 'Year': '2001',
#                 'index': 14},
#                {'Characteristic': 'Total - Male',
#                 'Count': '209710',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '1422',
#                 'Sex': 'Male',
#                 'Year': '2002',
#                 'index': 15},
#                {'Characteristic': 'Total - Male',
#                 'Count': '207921',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '1388',
#                 'Sex': 'Male',
#                 'Year': '2003',
#                 'index': 16},
#                {'Characteristic': 'Total - Male',
#                 'Count': '196906',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '1305',
#                 'Sex': 'Male',
#                 'Year': '2004',
#                 'index': 17},
#                {'Characteristic': 'Total - Male',
#                 'Count': '189298',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '1249',
#                 'Sex': 'Male',
#                 'Year': '2005',
#                 'index': 18},
#                {'Characteristic': 'Total - Male',
#                 'Count': '185418',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '1215',
#                 'Sex': 'Male',
#                 'Year': '2006',
#                 'index': 19},
#                {'Characteristic': 'Total - Male',
#                 'Count': '186631',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '1213',
#                 'Sex': 'Male',
#                 'Year': '2007',
#                 'index': 20},
#                {'Characteristic': 'Total - Male',
#                 'Count': '188035',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '1207',
#                 'Sex': 'Male',
#                 'Year': '2008',
#                 'index': 21},
#                {'Characteristic': 'Total - Male',
#                 'Count': '190118',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '1212',
#                 'Sex': 'Male',
#                 'Year': '2009',
#                 'index': 22},
#                {'Characteristic': 'Total - Male',
#                 'Count': '187699',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '1187',
#                 'Sex': 'Male',
#                 'Year': '2010',
#                 'index': 23},
#                {'Characteristic': 'Total - Male',
#                 'Count': '181510',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '1136',
#                 'Sex': 'Male',
#                 'Year': '2011',
#                 'index': 24},
#                {'Characteristic': 'Total - Male',
#                 'Count': '170734',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '1060',
#                 'Sex': 'Male',
#                 'Year': '2012',
#                 'index': 25},
#                {'Characteristic': 'Total - Female',
#                 'Count': '9089',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '67',
#                 'Sex': 'Female',
#                 'Year': '2000',
#                 'index': 26},
#                {'Characteristic': 'Total - Female',
#                 'Count': '9724',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '71',
#                 'Sex': 'Female',
#                 'Year': '2001',
#                 'index': 27},
#                {'Characteristic': 'Total - Female',
#                 'Count': '10336',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '74',
#                 'Sex': 'Female',
#                 'Year': '2002',
#                 'index': 28},
#                {'Characteristic': 'Total - Female',
#                 'Count': '10396',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '73',
#                 'Sex': 'Female',
#                 'Year': '2003',
#                 'index': 29},
#                {'Characteristic': 'Total - Female',
#                 'Count': '10464',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '73',
#                 'Sex': 'Female',
#                 'Year': '2004',
#                 'index': 30},
#                {'Characteristic': 'Total - Female',
#                 'Count': '10713',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '75',
#                 'Sex': 'Female',
#                 'Year': '2005',
#                 'index': 31},
#                {'Characteristic': 'Total - Female',
#                 'Count': '10768',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '75',
#                 'Sex': 'Female',
#                 'Year': '2006',
#                 'index': 32},
#                {'Characteristic': 'Total - Female',
#                 'Count': '11044',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '76',
#                 'Sex': 'Female',
#                 'Year': '2007',
#                 'index': 33},
#                {'Characteristic': 'Total - Female',
#                 'Count': '11036',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '75',
#                 'Sex': 'Female',
#                 'Year': '2008',
#                 'index': 34},
#                {'Characteristic': 'Total - Female',
#                 'Count': '11186',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '76',
#                 'Sex': 'Female',
#                 'Year': '2009',
#                 'index': 35},
#                {'Characteristic': 'Total - Female',
#                 'Count': '11277',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '75',
#                 'Sex': 'Female',
#                 'Year': '2010',
#                 'index': 36},
#                {'Characteristic': 'Total - Female',
#                 'Count': '10696',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '70',
#                 'Sex': 'Female',
#                 'Year': '2011',
#                 'index': 37},
#                {'Characteristic': 'Total - Female',
#                 'Count': '9942',
#                 'Race/ethnicity': None,
#                 'Rate per 100,000': '65',
#                 'Sex': 'Female',
#                 'Year': '2012',
#                 'index': 38},
#                {'Characteristic': 'Total - White, non-Hispanic',
#                 'Count': '59129',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '345',
#                 'Sex': None,
#                 'Year': '2000',
#                 'index': 39},
#                {'Characteristic': 'Total - White, non-Hispanic',
#                 'Count': '60836',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '349',
#                 'Sex': None,
#                 'Year': '2001',
#                 'index': 40},
#                {'Characteristic': 'Total - White, non-Hispanic',
#                 'Count': '62498',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '353',
#                 'Sex': None,
#                 'Year': '2002',
#                 'index': 41},
#                {'Characteristic': 'Total - White, non-Hispanic',
#                 'Count': '61052',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '340',
#                 'Sex': None,
#                 'Year': '2003',
#                 'index': 42},
#                {'Characteristic': 'Total - White, non-Hispanic',
#                 'Count': '59749',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '331',
#                 'Sex': None,
#                 'Year': '2004',
#                 'index': 43},
#                {'Characteristic': 'Total - White, non-Hispanic',
#                 'Count': '57006',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '316',
#                 'Sex': None,
#                 'Year': '2005',
#                 'index': 44},
#                {'Characteristic': 'Total - White, non-Hispanic',
#                 'Count': '54466',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '301',
#                 'Sex': None,
#                 'Year': '2006',
#                 'index': 45},
#                {'Characteristic': 'Total - White, non-Hispanic',
#                 'Count': '52669',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '289',
#                 'Sex': None,
#                 'Year': '2007',
#                 'index': 46},
#                {'Characteristic': 'Total - White, non-Hispanic',
#                 'Count': '52055',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '284',
#                 'Sex': None,
#                 'Year': '2008',
#                 'index': 47},
#                {'Characteristic': 'Total - White, non-Hispanic',
#                 'Count': '51343',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '281',
#                 'Sex': None,
#                 'Year': '2009',
#                 'index': 48},
#                {'Characteristic': 'Total - White, non-Hispanic',
#                 'Count': '49975',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '284',
#                 'Sex': None,
#                 'Year': '2010',
#                 'index': 49},
#                {'Characteristic': 'Total - White, non-Hispanic',
#                 'Count': '48219',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '274',
#                 'Sex': None,
#                 'Year': '2011',
#                 'index': 50},
#                {'Characteristic': 'Total - White, non-Hispanic',
#                 'Count': '44309',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '252',
#                 'Sex': None,
#                 'Year': '2012',
#                 'index': 51},
#                {'Characteristic': 'Total - Black, non-Hispanic',
#                 'Count': '104880',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '2732',
#                 'Sex': None,
#                 'Year': '2000',
#                 'index': 52},
#                {'Characteristic': 'Total - Black, non-Hispanic',
#                 'Count': '101386',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '2577',
#                 'Sex': None,
#                 'Year': '2001',
#                 'index': 53},
#                {'Characteristic': 'Total - Black, non-Hispanic',
#                 'Count': '98762',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '2461',
#                 'Sex': None,
#                 'Year': '2002',
#                 'index': 54},
#                {'Characteristic': 'Total - Black, non-Hispanic',
#                 'Count': '91538',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '2241',
#                 'Sex': None,
#                 'Year': '2003',
#                 'index': 55},
#                {'Characteristic': 'Total - Black, non-Hispanic',
#                 'Count': '88053',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '2134',
#                 'Sex': None,
#                 'Year': '2004',
#                 'index': 56},
#                {'Characteristic': 'Total - Black, non-Hispanic',
#                 'Count': '79797',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '1918',
#                 'Sex': None,
#                 'Year': '2005',
#                 'index': 57},
#                {'Characteristic': 'Total - Black, non-Hispanic',
#                 'Count': '78688',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '1865',
#                 'Sex': None,
#                 'Year': '2006',
#                 'index': 58},
#                {'Characteristic': 'Total - Black, non-Hispanic',
#                 'Count': '79176',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '1837',
#                 'Sex': None,
#                 'Year': '2007',
#                 'index': 59},
#                {'Characteristic': 'Total - Black, non-Hispanic',
#                 'Count': '82178',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '1862',
#                 'Sex': None,
#                 'Year': '2008',
#                 'index': 60},
#                {'Characteristic': 'Total - Black, non-Hispanic',
#                 'Count': '84161',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '1875',
#                 'Sex': None,
#                 'Year': '2009',
#                 'index': 61},
#                {'Characteristic': 'Total - Black, non-Hispanic',
#                 'Count': '83931',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '1865',
#                 'Sex': None,
#                 'Year': '2010',
#                 'index': 62},
#                {'Characteristic': 'Total - Black, non-Hispanic',
#                 'Count': '81714',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '1775',
#                 'Sex': None,
#                 'Year': '2011',
#                 'index': 63},
#                {'Characteristic': 'Total - Black, non-Hispanic',
#                 'Count': '75921',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '1623',
#                 'Sex': None,
#                 'Year': '2012',
#                 'index': 64},
#                {'Characteristic': 'Total - Hispanic',
#                 'Count': '48696',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '1004',
#                 'Sex': None,
#                 'Year': '2000',
#                 'index': 65},
#                {'Characteristic': 'Total - Hispanic',
#                 'Count': '50167',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '1012',
#                 'Sex': None,
#                 'Year': '2001',
#                 'index': 66},
#                {'Characteristic': 'Total - Hispanic',
#                 'Count': '51153',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '1017',
#                 'Sex': None,
#                 'Year': '2002',
#                 'index': 67},
#                {'Characteristic': 'Total - Hispanic',
#                 'Count': '51263',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '1007',
#                 'Sex': None,
#                 'Year': '2003',
#                 'index': 68},
#                {'Characteristic': 'Total - Hispanic',
#                 'Count': '49987',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '974',
#                 'Sex': None,
#                 'Year': '2004',
#                 'index': 69},
#                {'Characteristic': 'Total - Hispanic',
#                 'Count': '48588',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '941',
#                 'Sex': None,
#                 'Year': '2005',
#                 'index': 70},
#                {'Characteristic': 'Total - Hispanic',
#                 'Count': '48308',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '926',
#                 'Sex': None,
#                 'Year': '2006',
#                 'index': 71},
#                {'Characteristic': 'Total - Hispanic',
#                 'Count': '49336',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '932',
#                 'Sex': None,
#                 'Year': '2007',
#                 'index': 72},
#                {'Characteristic': 'Total - Hispanic',
#                 'Count': '48479',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '892',
#                 'Sex': None,
#                 'Year': '2008',
#                 'index': 73},
#                {'Characteristic': 'Total - Hispanic',
#                 'Count': '49510',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '888',
#                 'Sex': None,
#                 'Year': '2009',
#                 'index': 74},
#                {'Characteristic': 'Total - Hispanic',
#                 'Count': '48889',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '780',
#                 'Sex': None,
#                 'Year': '2010',
#                 'index': 75},
#                {'Characteristic': 'Total - Hispanic',
#                 'Count': '46482',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '724',
#                 'Sex': None,
#                 'Year': '2011',
#                 'index': 76},
#                {'Characteristic': 'Total - Hispanic',
#                 'Count': '41523',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '640',
#                 'Sex': None,
#                 'Year': '2012',
#                 'index': 77},
#                {'Characteristic': 'Total - Other race, non-Hispanic',
#                 'Count': '15350',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '826',
#                 'Sex': None,
#                 'Year': '2000',
#                 'index': 78},
#                {'Characteristic': 'Total - Other race, non-Hispanic',
#                 'Count': '15868',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '831',
#                 'Sex': None,
#                 'Year': '2001',
#                 'index': 79},
#                {'Characteristic': 'Total - Other race, non-Hispanic',
#                 'Count': '15739',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '805',
#                 'Sex': None,
#                 'Year': '2002',
#                 'index': 80},
#                {'Characteristic': 'Total - Other race, non-Hispanic',
#                 'Count': '15920',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '800',
#                 'Sex': None,
#                 'Year': '2003',
#                 'index': 81},
#                {'Characteristic': 'Total - Other race, non-Hispanic',
#                 'Count': '15903',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '792',
#                 'Sex': None,
#                 'Year': '2004',
#                 'index': 82},
#                {'Characteristic': 'Total - Other race, non-Hispanic',
#                 'Count': '15848',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '784',
#                 'Sex': None,
#                 'Year': '2005',
#                 'index': 83},
#                {'Characteristic': 'Total - Other race, non-Hispanic',
#                 'Count': '15873',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '777',
#                 'Sex': None,
#                 'Year': '2006',
#                 'index': 84},
#                {'Characteristic': 'Total - Other race, non-Hispanic',
#                 'Count': '15110',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '731',
#                 'Sex': None,
#                 'Year': '2007',
#                 'index': 85},
#                {'Characteristic': 'Total - Other race, non-Hispanic',
#                 'Count': '14484',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '689',
#                 'Sex': None,
#                 'Year': '2008',
#                 'index': 86},
#                {'Characteristic': 'Total - Other race, non-Hispanic',
#                 'Count': '13340',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '626',
#                 'Sex': None,
#                 'Year': '2009',
#                 'index': 87},
#                {'Characteristic': 'Total - Other race, non-Hispanic',
#                 'Count': '12802',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '504',
#                 'Sex': None,
#                 'Year': '2010',
#                 'index': 88},
#                {'Characteristic': 'Total - Other race, non-Hispanic',
#                 'Count': '11648',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '452',
#                 'Sex': None,
#                 'Year': '2011',
#                 'index': 89},
#                {'Characteristic': 'Total - Other race, non-Hispanic',
#                 'Count': '16478',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '613',
#                 'Sex': None,
#                 'Year': '2012',
#                 'index': 90},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '55602',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '639',
#                 'Sex': 'Male',
#                 'Year': '2000',
#                 'index': 91},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '57102',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '644',
#                 'Sex': 'Male',
#                 'Year': '2001',
#                 'index': 92},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '58313',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '647',
#                 'Sex': 'Male',
#                 'Year': '2002',
#                 'index': 93},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '56733',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '620',
#                 'Sex': 'Male',
#                 'Year': '2003',
#                 'index': 94},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '55179',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '598',
#                 'Sex': 'Male',
#                 'Year': '2004',
#                 'index': 95},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '52373',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '566',
#                 'Sex': 'Male',
#                 'Year': '2005',
#                 'index': 96},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '49788',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '535',
#                 'Sex': 'Male',
#                 'Year': '2006',
#                 'index': 97},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '47974',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '514',
#                 'Sex': 'Male',
#                 'Year': '2007',
#                 'index': 98},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '47410',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '504',
#                 'Sex': 'Male',
#                 'Year': '2008',
#                 'index': 99},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '46577',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '496',
#                 'Sex': 'Male',
#                 'Year': '2009',
#                 'index': 100},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '45219',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '504',
#                 'Sex': 'Male',
#                 'Year': '2010',
#                 'index': 101},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '43442',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '484',
#                 'Sex': 'Male',
#                 'Year': '2011',
#                 'index': 102},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '40090',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '446',
#                 'Sex': 'Male',
#                 'Year': '2012',
#                 'index': 103},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '101521',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '5358',
#                 'Sex': 'Male',
#                 'Year': '2000',
#                 'index': 104},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '97890',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '5010',
#                 'Sex': 'Male',
#                 'Year': '2001',
#                 'index': 105},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '95276',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '4751',
#                 'Sex': 'Male',
#                 'Year': '2002',
#                 'index': 106},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '88175',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '4303',
#                 'Sex': 'Male',
#                 'Year': '2003',
#                 'index': 107},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '84670',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '4072',
#                 'Sex': 'Male',
#                 'Year': '2004',
#                 'index': 108},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '76800',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '3653',
#                 'Sex': 'Male',
#                 'Year': '2005',
#                 'index': 109},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '75759',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '3541',
#                 'Sex': 'Male',
#                 'Year': '2006',
#                 'index': 110},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '76236',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '3491',
#                 'Sex': 'Male',
#                 'Year': '2007',
#                 'index': 111},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '79183',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '3542',
#                 'Sex': 'Male',
#                 'Year': '2008',
#                 'index': 112},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '81033',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '3565',
#                 'Sex': 'Male',
#                 'Year': '2009',
#                 'index': 113},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '80813',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '3588',
#                 'Sex': 'Male',
#                 'Year': '2010',
#                 'index': 114},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '78647',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '3396',
#                 'Sex': 'Male',
#                 'Year': '2011',
#                 'index': 115},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '73224',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '3102',
#                 'Sex': 'Male',
#                 'Year': '2012',
#                 'index': 116},
#                {'Characteristic': 'Hispanic',
#                 'Count': '46949',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '1765',
#                 'Sex': 'Male',
#                 'Year': '2000',
#                 'index': 117},
#                {'Characteristic': 'Hispanic',
#                 'Count': '48352',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '1781',
#                 'Sex': 'Male',
#                 'Year': '2001',
#                 'index': 118},
#                {'Characteristic': 'Hispanic',
#                 'Count': '49174',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '1790',
#                 'Sex': 'Male',
#                 'Year': '2002',
#                 'index': 119},
#                {'Characteristic': 'Hispanic',
#                 'Count': '49180',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '1777',
#                 'Sex': 'Male',
#                 'Year': '2003',
#                 'index': 120},
#                {'Characteristic': 'Hispanic',
#                 'Count': '47798',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '1723',
#                 'Sex': 'Male',
#                 'Year': '2004',
#                 'index': 121},
#                {'Characteristic': 'Hispanic',
#                 'Count': '46265',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '1666',
#                 'Sex': 'Male',
#                 'Year': '2005',
#                 'index': 122},
#                {'Characteristic': 'Hispanic',
#                 'Count': '45848',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '1641',
#                 'Sex': 'Male',
#                 'Year': '2006',
#                 'index': 123},
#                {'Characteristic': 'Hispanic',
#                 'Count': '46830',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '1662',
#                 'Sex': 'Male',
#                 'Year': '2007',
#                 'index': 124},
#                {'Characteristic': 'Hispanic',
#                 'Count': '46023',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '1599',
#                 'Sex': 'Male',
#                 'Year': '2008',
#                 'index': 125},
#                {'Characteristic': 'Hispanic',
#                 'Count': '47140',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '1600',
#                 'Sex': 'Male',
#                 'Year': '2009',
#                 'index': 126},
#                {'Characteristic': 'Hispanic',
#                 'Count': '46546',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '1405',
#                 'Sex': 'Male',
#                 'Year': '2010',
#                 'index': 127},
#                {'Characteristic': 'Hispanic',
#                 'Count': '44268',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '1308',
#                 'Sex': 'Male',
#                 'Year': '2011',
#                 'index': 128},
#                {'Characteristic': 'Hispanic',
#                 'Count': '39631',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '1165',
#                 'Sex': 'Male',
#                 'Year': '2012',
#                 'index': 129},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '14504',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '1557',
#                 'Sex': 'Male',
#                 'Year': '2000',
#                 'index': 130},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '14897',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '1558',
#                 'Sex': 'Male',
#                 'Year': '2001',
#                 'index': 131},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '14699',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '1497',
#                 'Sex': 'Male',
#                 'Year': '2002',
#                 'index': 132},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '15010',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '1500',
#                 'Sex': 'Male',
#                 'Year': '2003',
#                 'index': 133},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '14976',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '1479',
#                 'Sex': 'Male',
#                 'Year': '2004',
#                 'index': 134},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '14565',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '1427',
#                 'Sex': 'Male',
#                 'Year': '2005',
#                 'index': 135},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '14431',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '1395',
#                 'Sex': 'Male',
#                 'Year': '2006',
#                 'index': 136},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '13626',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '1300',
#                 'Sex': 'Male',
#                 'Year': '2007',
#                 'index': 137},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '13084',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '1226',
#                 'Sex': 'Male',
#                 'Year': '2008',
#                 'index': 138},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '12127',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '1121',
#                 'Sex': 'Male',
#                 'Year': '2009',
#                 'index': 139},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '11651',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '912',
#                 'Sex': 'Male',
#                 'Year': '2010',
#                 'index': 140},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '10699',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '824',
#                 'Sex': 'Male',
#                 'Year': '2011',
#                 'index': 141},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '15227',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '1124',
#                 'Sex': 'Male',
#                 'Year': '2012',
#                 'index': 142},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '3498',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '41',
#                 'Sex': 'Female',
#                 'Year': '2000',
#                 'index': 143},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '3725',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '43',
#                 'Sex': 'Female',
#                 'Year': '2001',
#                 'index': 144},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '4165',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '48',
#                 'Sex': 'Female',
#                 'Year': '2002',
#                 'index': 145},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '4301',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '49',
#                 'Sex': 'Female',
#                 'Year': '2003',
#                 'index': 146},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '4560',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '52',
#                 'Sex': 'Female',
#                 'Year': '2004',
#                 'index': 147},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '4640',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '53',
#                 'Sex': 'Female',
#                 'Year': '2005',
#                 'index': 148},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '4684',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '53',
#                 'Sex': 'Female',
#                 'Year': '2006',
#                 'index': 149},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '4695',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '53',
#                 'Sex': 'Female',
#                 'Year': '2007',
#                 'index': 150},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '4656',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '52',
#                 'Sex': 'Female',
#                 'Year': '2008',
#                 'index': 151},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '4769',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '54',
#                 'Sex': 'Female',
#                 'Year': '2009',
#                 'index': 152},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '4757',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '55',
#                 'Sex': 'Female',
#                 'Year': '2010',
#                 'index': 153},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '4777',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '55',
#                 'Sex': 'Female',
#                 'Year': '2011',
#                 'index': 154},
#                {'Characteristic': 'White, non-Hispanic',
#                 'Count': '4219',
#                 'Race/ethnicity': 'White, non-Hispanic',
#                 'Rate per 100,000': '49',
#                 'Sex': 'Female',
#                 'Year': '2012',
#                 'index': 155},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '3500',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '180',
#                 'Sex': 'Female',
#                 'Year': '2000',
#                 'index': 156},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '3575',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '181',
#                 'Sex': 'Female',
#                 'Year': '2001',
#                 'index': 157},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '3561',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '177',
#                 'Sex': 'Female',
#                 'Year': '2002',
#                 'index': 158},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '3466',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '170',
#                 'Sex': 'Female',
#                 'Year': '2003',
#                 'index': 159},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '3408',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '166',
#                 'Sex': 'Female',
#                 'Year': '2004',
#                 'index': 160},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '3100',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '151',
#                 'Sex': 'Female',
#                 'Year': '2005',
#                 'index': 161},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '3021',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '145',
#                 'Sex': 'Female',
#                 'Year': '2006',
#                 'index': 162},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '3031',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '143',
#                 'Sex': 'Female',
#                 'Year': '2007',
#                 'index': 163},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '3104',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '143',
#                 'Sex': 'Female',
#                 'Year': '2008',
#                 'index': 164},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '3207',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '145',
#                 'Sex': 'Female',
#                 'Year': '2009',
#                 'index': 165},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '3182',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '142',
#                 'Sex': 'Female',
#                 'Year': '2010',
#                 'index': 166},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '3097',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '135',
#                 'Sex': 'Female',
#                 'Year': '2011',
#                 'index': 167},
#                {'Characteristic': 'Black, non-Hispanic',
#                 'Count': '2745',
#                 'Race/ethnicity': 'Black, non-Hispanic',
#                 'Rate per 100,000': '118',
#                 'Sex': 'Female',
#                 'Year': '2012',
#                 'index': 168},
#                {'Characteristic': 'Hispanic',
#                 'Count': '1596',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '73',
#                 'Sex': 'Female',
#                 'Year': '2000',
#                 'index': 169},
#                {'Characteristic': 'Hispanic',
#                 'Count': '1684',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '75',
#                 'Sex': 'Female',
#                 'Year': '2001',
#                 'index': 170},
#                {'Characteristic': 'Hispanic',
#                 'Count': '1841',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '81',
#                 'Sex': 'Female',
#                 'Year': '2002',
#                 'index': 171},
#                {'Characteristic': 'Hispanic',
#                 'Count': '1958',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '84',
#                 'Sex': 'Female',
#                 'Year': '2003',
#                 'index': 172},
#                {'Characteristic': 'Hispanic',
#                 'Count': '2100',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '89',
#                 'Sex': 'Female',
#                 'Year': '2004',
#                 'index': 173},
#                {'Characteristic': 'Hispanic',
#                 'Count': '2247',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '94',
#                 'Sex': 'Female',
#                 'Year': '2005',
#                 'index': 174},
#                {'Characteristic': 'Hispanic',
#                 'Count': '2403',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '99',
#                 'Sex': 'Female',
#                 'Year': '2006',
#                 'index': 175},
#                {'Characteristic': 'Hispanic',
#                 'Count': '2464',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '100',
#                 'Sex': 'Female',
#                 'Year': '2007',
#                 'index': 176},
#                {'Characteristic': 'Hispanic',
#                 'Count': '2407',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '94',
#                 'Sex': 'Female',
#                 'Year': '2008',
#                 'index': 177},
#                {'Characteristic': 'Hispanic',
#                 'Count': '2303',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '88',
#                 'Sex': 'Female',
#                 'Year': '2009',
#                 'index': 178},
#                {'Characteristic': 'Hispanic',
#                 'Count': '2291',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '78',
#                 'Sex': 'Female',
#                 'Year': '2010',
#                 'index': 179},
#                {'Characteristic': 'Hispanic',
#                 'Count': '2166',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '71',
#                 'Sex': 'Female',
#                 'Year': '2011',
#                 'index': 180},
#                {'Characteristic': 'Hispanic',
#                 'Count': '1847',
#                 'Race/ethnicity': 'Hispanic',
#                 'Rate per 100,000': '60',
#                 'Sex': 'Female',
#                 'Year': '2012',
#                 'index': 181},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '869',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '94',
#                 'Sex': 'Female',
#                 'Year': '2000',
#                 'index': 182},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '988',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '104',
#                 'Sex': 'Female',
#                 'Year': '2001',
#                 'index': 183},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '1052',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '108',
#                 'Sex': 'Female',
#                 'Year': '2002',
#                 'index': 184},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '932',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '94',
#                 'Sex': 'Female',
#                 'Year': '2003',
#                 'index': 185},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '964',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '97',
#                 'Sex': 'Female',
#                 'Year': '2004',
#                 'index': 186},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '1289',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '129',
#                 'Sex': 'Female',
#                 'Year': '2005',
#                 'index': 187},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '1410',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '140',
#                 'Sex': 'Female',
#                 'Year': '2006',
#                 'index': 188},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '1429',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '140',
#                 'Sex': 'Female',
#                 'Year': '2007',
#                 'index': 189},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '1361',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '132',
#                 'Sex': 'Female',
#                 'Year': '2008',
#                 'index': 190},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '1208',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '115',
#                 'Sex': 'Female',
#                 'Year': '2009',
#                 'index': 191},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '1154',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '91',
#                 'Sex': 'Female',
#                 'Year': '2010',
#                 'index': 192},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '964',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '75',
#                 'Sex': 'Female',
#                 'Year': '2011',
#                 'index': 193},
#                {'Characteristic': 'Other race, non-Hispanic',
#                 'Count': '1267',
#                 'Race/ethnicity': 'Other race, non-Hispanic',
#                 'Rate per 100,000': '95',
#                 'Sex': 'Female',
#                 'Year': '2012',
#                 'index': 194}]}
